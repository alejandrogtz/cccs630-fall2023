# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/alejandrogtz/cccs630-fall2023/blob/main/module03/agent-based_introduction.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Introduction to Agent-Based Simulators

# %% [markdown]
# ## Introduction
#
# Now that we have covered two cellular automata in the course, we will continue to increase the level of sophistication and complexity of our models and simulations.
#
# In this module, we will add the concept of agents to our knowledge. These agents are TODO and use them to study the behaviours that occur in the system when we test different thresholds or policies.

# %% [markdown]
# In preparation for the module, please review the following introductory article about agent-based models.
#
# https://simudyne.com/resources/how-do-agent-based-models-work/

# %% [markdown]
# ## Concepts
#
# Below you will find a list of important concepts we will review in the module.
#
# - Agent-based models
# - Agents
# - Schelling's model
# - Segregation models
# - Policies TODO?

# %% [markdown]
# ## Interaction
#
# In this interaction, we will study Schelling's segregation model. The model was created by the American economist Thomas Schelling in the 1970s.
#
# The model has two types of agents, agent types A and B, that operate on a two-dimensional grid (similar to Conway's cellular automata). Each cell of the grid can be in one of three states:
#
# - Occupied by a agent type 1 (red)
# - Occupied by a agent type 2 (blue)
# - Unoccupied or vacant, and represented by a zero on the grid (white)
#
# Visually, the initial grid looks like the following image.
#
# <img src="https://drive.google.com/uc?export=view&id=1bGUkcSTB6Y9cCKXNt3T4-gGZ3_Q0nVTH" width="300" />
#
# Each agent, whether type A or B, has a preference regarding the type of neighbours they want to be surrounded by. An agent wants at least a certain fraction of its neighbours to be of the same type. If this preference is not met, the agent is considered "unhappy" and will want to move. In each discrete cycle, all unhappy agents are first identified and then transfer to a vacant location randomly.
#
# Schelling's model explains how small preferences for one's neighbours to be of the same type can lead to large-scale patterns of segregation, even when individuals do not have an intrinsic or strong preference to be separated from others.
#
# ### Instructions
#
# - Simulate the following tolerance thresholds for the agents:
#     - High tolerance, threshold < 0.2
#     - Average tolerance, threshold > 0.2 and threshold < 0.7
#     - Low tolerance, threshold < 0.3
# - Analyze the patterns that emerge on the grid.

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

from matplotlib import animation, rc, colors

rc('animation', html='html5')

# %%
# Function to create a grid with randomly allocated agents
# On the grid: 0 = empty (white), 1 = agent type 1 (red), 2 = agent type 2 (blue)
def initialize_grid(grid_size, minority_ratio):    
    grid = np.random.choice([0, 1, 2], size=(grid_size, grid_size), p=[1 - minority_ratio, minority_ratio / 2, minority_ratio / 2])
    return grid

# %%
# Function to count the number of similar neighbors
def count_neighbors(grid, axis_0, axis_1, agent_type, radius=1):
    neighbors = grid[max(0, axis_0 - radius): min(axis_0 + radius + 1, grid.shape[0]),
                     max(0, axis_1 - radius): min(axis_1 + radius + 1, grid.shape[1])]
    return np.count_nonzero(neighbors == agent_type)

# %%
# Function to determine the average happiness level and the number of happy agents on the grid
def calculate_grid_happiness(grid_history,threshold):
    avg_happines = []
    count_happy_agents = []


    
    for grid in grid_history:
        
        agents = np.argwhere(grid >= 1)
        total_agents = len (agents)
        print (total_agents)
        
        agent_happiness = []
        happy_agents = 0
        for x in range(grid.shape[0]):
            for y in range(grid.shape[1]):
                if grid[x, y]>0: # Ignore empty spaces
                    happiness = calculate_happiness(grid,x,y)
                    agent_happiness.append(happiness)
                    if (happiness>=threshold):
                        happy_agents += 1
        avg_happines.append(sum(agent_happiness)/len(agent_happiness))
        count_happy_agents.append(happy_agents/total_agents)
    
    return (avg_happines,count_happy_agents)

# %%
# Function to determine the happiness level of a cell.
def calculate_happiness(grid, axis_0, axis_1, radius=1):
    agent_type = grid[axis_0, axis_1] # Agent type of the cell
    
    agent_types = [1 , 2]
    agent_types.remove(agent_type)
     
    different_neighbors = count_neighbors(grid, axis_0, axis_1, agent_types.pop(0), radius) # Count number neighbors of different type
    
    similar_neighbors = count_neighbors(grid, axis_0, axis_1, agent_type, radius) - 1  # Count excludes the agent itself

    total_neighbors = similar_neighbors + different_neighbors
    
    if total_neighbors == 0:
        return 0
    
    return similar_neighbors / total_neighbors

# %%
def identify_unhappy_agents(grid, threshold, radius=1):
    unhappy_agents = []
    for axis_0 in range(grid.shape[0]):
        for axis_1 in range(grid.shape[1]):
            if grid[axis_0, axis_1]>0:
                if (calculate_happiness(grid, axis_0, axis_1, radius)<threshold):
                    unhappy_agents.append([axis_0,axis_1])
    return(unhappy_agents)

# %%
def move_unhappy_agents(grid, unhappy_agents, threshold, radius=1):
    new_grid = grid.copy()
    for unhappy_agent in unhappy_agents:
        axis_0, axis_1 = unhappy_agent
        empty_spaces = np.argwhere(new_grid == 0)
        if len(empty_spaces) > 0:
            np.random.shuffle(empty_spaces)
            new_axis_0, new_axis_1 = empty_spaces[0]
            new_grid[new_axis_0, new_axis_1] = grid[axis_0, axis_1]
            new_grid[axis_0, axis_1] = 0
    return new_grid

# %%
def move_unhappy_agents3(grid, unhappy_agents, threshold, radius=1):
    new_grid = grid.copy()
    for unhappy_agent in unhappy_agents:
        axis_0, axis_1 = unhappy_agent
        empty_spaces = np.argwhere(new_grid == 0)
        if len(empty_spaces) > 0:
            np.random.shuffle(empty_spaces)
            for empty_space in empty_spaces:
                new_axis_0, new_axis_1 = empty_space
                new_grid[new_axis_0, new_axis_1] = grid[axis_0, axis_1]
                new_grid[axis_0, axis_1] = 0
                if (calculate_happiness(new_grid, new_axis_0, new_axis_1, radius)>=threshold):
                    break
                else: 
                    new_grid[axis_0, axis_1] = grid[axis_0, axis_1]
                    new_grid[new_axis_0, new_axis_1] = 0
    return new_grid

# %%
def move_unhappy_agents2(grid, threshold, radius=1):
    new_grid = grid.copy()
    for axis_0 in range(new_grid.shape[0]):
        for axis_1 in range(new_grid.shape[1]):
            
            if new_grid[axis_0, axis_1]>0: # Ignore empty spaces 
                happiness = calculate_happiness(new_grid, axis_0, axis_1, radius)

                if happiness < threshold:
                    
                    empty_spaces = np.argwhere(new_grid == 0)
                    
                    #print ("Before 0",empty_spaces)
                    
                    #print ("empty_spaces start")
                    #print (empty_spaces)
                    #print ("empty_spaces end")
                    if len(empty_spaces) > 0:
                        #print ("Random")
                        #print (np.random.randint(len(empty_spaces)))
                        #TODO DECIDE new_x, new_y = empty_spaces[np.random.randint(len(empty_spaces))] # Assign the agent to an empty location
                        
                        ##
                        
                        #print ("Before",empty_spaces)
                        #print (len(empty_spaces))
                        #random.shuffle(empty_spaces)
                        np.random.shuffle(empty_spaces)
                        #print ("After",empty_spaces)
                        #print (len(empty_spaces))
                        for empty_space in empty_spaces:
                            #print ("First space")
                            #print (empty_space)
                            new_axis_0, new_axis_1 = empty_space
                            #print (empty_space_x, empty_space_y)
                            new_grid[new_axis_0, new_axis_1] = new_grid[axis_0, axis_1]
                            new_grid[axis_0, axis_1] = 0
                            if (calculate_happiness(new_grid, new_axis_0, new_axis_1, radius)>=threshold):
                                break
                            else: 
                                new_grid[axis_0, axis_1] = new_grid[new_axis_0, new_axis_1]
                                new_grid[new_axis_0, new_axis_1] = 0
                                
                        #if (new_x!=''):
                         #   new_grid[new_x, new_y] = new_grid[x, y]
                          #  new_grid[x, y] = 0
                        #print ("new x, new y")
                        #print (new_x, new_y)
                        
    return new_grid

# %%
# Function to debug the code. The function shows a single grid.
def visualize_grid(grid): 
    custom_cmap = colors.LinearSegmentedColormap.from_list("", ["white","red","blue"])
    plt.imshow(grid, cmap=custom_cmap, vmin=0, vmax=2)
    plt.xticks([]) # Remove the x-axis information
    plt.yticks([]) # Remove the y-axis information
    plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def schelling_model(grid_size=20, minority_ratio=0.2, threshold=0.3, max_iterations=100, radius=1):
    grid = initialize_grid(grid_size, minority_ratio)
    grid_history = [grid.copy()]

    for i in range(max_iterations):
        unhappy_agents = identify_unhappy_agents(grid, threshold, radius)
        new_grid = move_unhappy_agents(grid, unhappy_agents, threshold, radius)
        
        if np.array_equal(grid, new_grid):  # Converged, no more movements needed
            break
        grid = new_grid
        grid_history.append(grid.copy())

    return grid_history

# %%
# Increasing the threshold incresases the agent intolerance
grid_history = schelling_model(grid_size=100, minority_ratio=0.7, threshold=0.7, max_iterations=20, radius=1)

# %%
avg_happines, count_happy_agents = calculate_grid_happiness(grid_history, .7)
# Out:
# 7022
# 7022
# 7022
# 7022
# 7022
# 7022
# 7022
# 7022
# 7022
# 7022
# 7022
# 7022
# 7022
# 7022
# 7022
# 7022
# 7022
# 7022
# 7022
# 7022
# 7022

# %%
plt.plot(count_happy_agents)
plt.title("Grid Happiness Level")
plt.xlabel("Iteration")
plt.ylabel("Average Happiness Level")
plt.show()

# %%
fig = plt.figure()
    
images = []
    
custom_cmap = colors.LinearSegmentedColormap.from_list("", ["white","red","blue"])

for grid in grid_history:
    image = plt.imshow(grid, cmap=custom_cmap, vmin=0, vmax=2)
    plt.xticks([])
    plt.yticks([])
    images.append([image])

# %%
ani = animation.ArtistAnimation(fig, images, interval=500, blit=True, repeat=False) # Create the animation

# %%
ani # Display the animation
# Out:
# <video width="432" height="288" controls autoplay>
#   <source type="video/mp4" src="...

# %%
grid_test = initialize_grid(5,.5)

# %%
visualize_grid(grid_test)

# %%
identify_unhappy_agents(grid_test,.9)
# Out:
# [[0, 4],
#  [1, 3],
#  [2, 0],
#  [2, 1],
#  [2, 2],
#  [3, 1],
#  [3, 3],
#  [4, 0],
#  [4, 1],
#  [4, 3],
#  [4, 4]]

# %%
count_neighbors(grid_test,0,0,2)
# Out:
# Grid ------------------
# [[2 1 0 1 2]
#  [1 1 1 0 0]
#  [2 1 0 1 0]
#  [0 2 0 2 2]
#  [0 2 2 0 0]]
# Grid.shape[0] ------------------
# 5
# Neighbors ------------------
# [[2 1]
#  [1 1]]
# 1

# %%
calculate_happiness(grid_test,0,0)
# Out:
# Grid ------------------
# [[2 1 0 1 2]
#  [1 1 1 0 0]
#  [2 1 0 1 0]
#  [0 2 0 2 2]
#  [0 2 2 0 0]]
# Grid.shape[0] ------------------
# 5
# Neighbors ------------------
# [[2 1]
#  [1 1]]
# Grid ------------------
# [[2 1 0 1 2]
#  [1 1 1 0 0]
#  [2 1 0 1 0]
#  [0 2 0 2 2]
#  [0 2 2 0 0]]
# Grid.shape[0] ------------------
# 5
# Neighbors ------------------
# [[2 1]
#  [1 1]]
# x,y 0,0 similar_neighbors 0 total_neighbors 3
# 0.0

# %%
new_grid_test = move_unhappy_agents(grid_test, .3, 1)
# Out:
# Grid ------------------
# [[2 1 2]
#  [0 2 0]
#  [0 0 0]]
# Grid.shape[0] ------------------
# 3
# Manual Selection ------------------
# [[2 1 2]
#  [0 2 0]]
# Neighbors ------------------
# [[2 1]
#  [0 2]]
# Grid ------------------
# [[2 1 2]
#  [0 2 0]
#  [0 0 0]]
# Grid.shape[0] ------------------
# 3
# Manual Selection ------------------
# [[2 1 2]
#  [0 2 0]]
# Neighbors ------------------
# [[2 1]
#  [0 2]]
# x,y 0,0 similar_neighbors 1 total_neighbors 2
# Grid ------------------
# [[2 1 2]
#  [0 2 0]
#  [0 0 0]]
# Grid.shape[0] ------------------
# 3
# Manual Selection ------------------
# [[2 1 2]
#  [0 2 0]]
# Neighbors ------------------
# [[2 1 2]
#  [0 2 0]]
# Grid ------------------
# [[2 1 2]
#  [0 2 0]
#  [0 0 0]]
# Grid.shape[0] ------------------
# 3
# Manual Selection ------------------
# [[2 1 2]
#  [0 2 0]]
# Neighbors ------------------
# [[2 1 2]
#  [0 2 0]]
# x,y 0,1 similar_neighbors 0 total_neighbors 3
# [[1 0]
#  [1 2]
#  [2 0]
#  [2 1]
#  [2 2]]
# Grid ------------------
# [[2 0 2]
#  [0 2 0]
#  [1 0 0]]
# Grid.shape[0] ------------------
# 3
# Manual Selection ------------------
# [[2 0 2]
#  [0 2 0]]
# Neighbors ------------------
# [[0 2]
#  [2 0]]
# Grid ------------------
# [[2 0 2]
#  [0 2 0]
#  [1 0 0]]
# Grid.shape[0] ------------------
# 3
# Manual Selection ------------------
# [[2 0 2]
#  [0 2 0]]
# Neighbors ------------------
# [[0 2]
#  [2 0]]
# x,y 0,2 similar_neighbors 1 total_neighbors 1
# Grid ------------------
# [[2 0 2]
#  [0 2 0]
#  [1 0 0]]
# Grid.shape[0] ------------------
# 3
# Manual Selection ------------------
# [[2 0 2]
#  [0 2 0]]
# Neighbors ------------------
# [[2 0 2]
#  [0 2 0]
#  [1 0 0]]
# Grid ------------------
# [[2 0 2]
#  [0 2 0]
#  [1 0 0]]
# Grid.shape[0] ------------------
# 3
# Manual Selection ------------------
# [[2 0 2]
#  [0 2 0]]
# Neighbors ------------------
# [[2 0 2]
#  [0 2 0]
#  [1 0 0]]
# x,y 1,1 similar_neighbors 2 total_neighbors 3
# Grid ------------------
# [[2 0 2]
#  [0 2 0]
#  [1 0 0]]
# Grid.shape[0] ------------------
# 3
# Manual Selection ------------------
# [[2 0 2]
#  [0 2 0]]
# Neighbors ------------------
# [[0 2]
#  [1 0]]
# Grid ------------------
# [[2 0 2]
#  [0 2 0]
#  [1 0 0]]
# Grid.shape[0] ------------------
# 3
# Manual Selection ------------------
# [[2 0 2]
#  [0 2 0]]
# Neighbors ------------------
# [[0 2]
#  [1 0]]
# x,y 2,0 similar_neighbors 0 total_neighbors 1
# [[0 1]
#  [1 0]
#  [1 2]
#  [2 1]
#  [2 2]]

# %%
visualize_grid(new_grid_test)

# %%
calculate_grid_happiness(new_grid_test)
# Out:
# Grid ------------------
# [[2 1 2]
#  [0 2 0]
#  [0 0 0]]
# Grid.shape[0] ------------------
# 3
# Manual Selection ------------------
# [[2 1 2]
#  [0 2 0]]
# Neighbors ------------------
# [[2 1]
#  [0 2]]
# Grid ------------------
# [[2 1 2]
#  [0 2 0]
#  [0 0 0]]
# Grid.shape[0] ------------------
# 3
# Manual Selection ------------------
# [[2 1 2]
#  [0 2 0]]
# Neighbors ------------------
# [[2 1]
#  [0 2]]
# x,y 0,0 similar_neighbors 1 total_neighbors 2
# Grid ------------------
# [[2 1 2]
#  [0 2 0]
#  [0 0 0]]
# Grid.shape[0] ------------------
# 3
# Manual Selection ------------------
# [[2 1 2]
#  [0 2 0]]
# Neighbors ------------------
# [[2 1 2]
#  [0 2 0]]
# Grid ------------------
# [[2 1 2]
#  [0 2 0]
#  [0 0 0]]
# Grid.shape[0] ------------------
# 3
# Manual Selection ------------------
# [[2 1 2]
#  [0 2 0]]
# Neighbors ------------------
# [[2 1 2]
#  [0 2 0]]
# x,y 0,1 similar_neighbors 0 total_neighbors 3
# Grid ------------------
# [[2 1 2]
#  [0 2 0]
#  [0 0 0]]
# Grid.shape[0] ------------------
# 3
# Manual Selection ------------------
# [[2 1 2]
#  [0 2 0]]
# Neighbors ------------------
# [[1 2]
#  [2 0]]
# Grid ------------------
# [[2 1 2]
#  [0 2 0]
#  [0 0 0]]
# Grid.shape[0] ------------------
# 3
# Manual Selection ------------------
# [[2 1 2]
#  [0 2 0]]
# Neighbors ------------------
# [[1 2]
#  [2 0]]
# x,y 0,2 similar_neighbors 1 total_neighbors 2
# Grid ------------------
# [[2 1 2]
#  [0 2 0]
#  [0 0 0]]
# Grid.shape[0] ------------------
# 3
# Manual Selection ------------------
# [[2 1 2]
#  [0 2 0]]
# Neighbors ------------------
# [[2 1 2]
#  [0 2 0]
#  [0 0 0]]
# Grid ------------------
# [[2 1 2]
#  [0 2 0]
#  [0 0 0]]
# Grid.shape[0] ------------------
# 3
# Manual Selection ------------------
# [[2 1 2]
#  [0 2 0]]
# Neighbors ------------------
# [[2 1 2]
#  [0 2 0]
#  [0 0 0]]
# x,y 1,1 similar_neighbors 2 total_neighbors 3
# 0.41666666666666663

# %%
grid_test.shape[1]
# Out:
# 3

# %%
list_a = [[1,2],[2,2],[3,4]]
random.shuffle(list_a)

# %%
print(list_a)
# Out:
# [[3, 4], [1, 2], [2, 2]]

# %% [markdown]
# ## Recommended Readings
#
# Once you have completed the interaction portion of the module, please read the following recommended reading.
#
# - Chapter 2 - Simple Rules, Pages 46 - 45. Tranquillo, J. V. (2019). An introduction to complex systems: Making sense of a changing world. Springer. https://mcgill.on.worldcat.org/oclc/1087498746
