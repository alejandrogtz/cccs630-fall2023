# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/alejandrogtz/cccs630-fall2023/blob/main/module12/evolutionary_algorithms_applications.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Applications of Evolutionary Algorithms
#
# ## Introduction
#
# In this module, we will apply evolutionary algorithms to solve routing problems. Please watch the following video about the travelling salesperson problem in preparation for the module's interaction portion.

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/Ov0EetgMws4" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>

# %% [markdown]
# ## Concepts
#
# You will find a list of important concepts we will review in the module below.
#
# - Traveling salesperson problem
# - Optimization
# - Routes

# %% [markdown]
# ## Interaction

# %% [markdown]
# In this interaction, we will solve the travelling salesperson problem using a greedy approach and a genetic algorithm. We will compare the produced results and review the advantages and disadvantages of both approaches.
#
# The travelling salesperson problem consists of determining the order in which a person should visit several cities or locations a single time and return to the starting location at the end.

# %%
pip install deap

# %%
import numpy as np
import random
import pandas as pd
import math
import geopandas as gpd
from shapely.geometry import Point
import matplotlib.pyplot as plt
#import contextily as ctx

# %%
data = pd.read_excel('points_of_interest.xlsx', sheet_name='points_of_interest') # Load the data into a Pandas Dataframe

# %%
data
# Out:
#         ID              Famille                  Catégorie  \
# 0        1             Culturel     Établissement culturel
# 1        2             Culturel     Établissement culturel
# 2        3           Commercial  Regroupement de commerces
# 3        4             Culturel     Établissement culturel
# 4        5  Récréatif / sportif  Parc et autre espace vert
# ...    ...                  ...                        ...
# 3226  3458  Récréatif / sportif   Équipement communautaire
# 3227  3459           Commercial  Regroupement de commerces
# 3228  3460           Commercial  Regroupement de commerces
# 3229  3461           Commercial  Regroupement de commerces
# 3230  3462           Commercial  Regroupement de commerces
#
#                           Nom français Nom court  \
# 0                    Maison du Meunier       NaN
# 1                   Maison du Pressoir       NaN
# 2                       Marché Central       NaN
# 3     Musée des Sœurs de la Providence       NaN
# 4                        Parc Ahuntsic       NaN
# ...                                ...       ...
# 3226                   Centre Appleton       NaN
# 3227             Les Galleries d'Anjou       NaN
# 3228                    Place Bourassa       NaN
# 3229                       Place Vertu       NaN
# 3230               Carrefour Angrignon       NaN
#
#                                                  Type  Numéro  \
# 0     Musée et centre d'interprétation / d'exposition   10897
# 1     Musée et centre d'interprétation / d'exposition   10865
# 2                                   Centre commercial    9187
# 3     Musée et centre d'interprétation / d'exposition  12055
# 4                                                Parc
# ...                                               ...     ...
# 3226     Organisme communautaire et centre de loisirs    6585
# 3227                                Centre commercial    7999
# 3228                                Centre commercial    6000
# 3229                                Centre commercial    3131
# 3230                                Centre commercial    7077
#
#                                   rue  Étage Bureau     Ville Code postal  \
# 0                         Rue du Pont      0         Montréal     H2B 1Z4
# 1                     Rue du Pressoir      0         Montréal     H2B 2L1
# 2               Boulevard de l'Acadie      0         Montréal     H4N 3K1
# 3                          Rue Grenet      0         Montréal     H4J 2J5
# 4                                          0         Montréal     H3L 2E5
# ...                               ...    ...    ...       ...         ...
# 3226     Chemin de la Côte-des-Neiges      0         Montréal     H3S 2A5
# 3227  Boulevard des Galeries d'Anjou,      0         Montréal     H1M 1W9
# 3228         Boulevard Henri-Bourassa      0         Montréal     H1G 2T6
# 3229       Boulevard de la Côte-Vertu      0         Montréal     H4R 1Y8
# 3230                 Boulevard Newman      0         Montréal     H8N 1X1
#
#                            Arrondissement Classification  Longitude   Latitude
# 0                   Ahuntsic-Cartierville       niveau 3 -73.661102  45.574862
# 1                   Ahuntsic-Cartierville       niveau 3 -73.659553  45.575970
# 2                   Ahuntsic-Cartierville       niveau 1 -73.654956  45.534023
# 3                   Ahuntsic-Cartierville       niveau 3 -73.713635  45.529374
# 4                   Ahuntsic-Cartierville       niveau 2 -73.664710  45.555801
# ...                                   ...            ...        ...        ...
# 3226  Côte-des-Neiges–Notre-Dame-de-Grâce       niveau 3 -73.635287  45.502481
# 3227                                Anjou       niveau 1 -73.564512  45.600636
# 3228                        Montréal-Nord       niveau 2 -73.616778  45.606041
# 3229                        Saint-Laurent       niveau 1 -73.706614  45.498756
# 3230                              LaSalle       niveau 1 -73.615478  45.447801
#
# [3231 rows x 16 columns]

# %%
data['Longitude'].head()
# Out:
# 0   -73.661102
# 1   -73.659553
# 2   -73.654956
# 3   -73.713635
# 4   -73.664710
# Name: Longitude, dtype: float64

# %%
data.Longitude.head()
# Out:
# 0   -73.661102
# 1   -73.659553
# 2   -73.654956
# 3   -73.713635
# 4   -73.664710
# Name: Longitude, dtype: float64

# %%
data['Latitude'].head()
# Out:
# 0    45.574862
# 1    45.575970
# 2    45.534023
# 3    45.529374
# 4    45.555801
# Name: Latitude, dtype: float64

# %%
data.loc[0] # Access the first row via its primary label
# Out:
# ID                                                              1
# Famille                                                  Culturel
# Catégorie                                  Établissement culturel
# Nom français                                    Maison du Meunier
# Nom court                                                     NaN
# Type              Musée et centre d'interprétation / d'exposition
# Numéro                                                      10897
# rue                                                   Rue du Pont
# Étage                                                           0
# Bureau
# Ville                                                    Montréal
# Code postal                                               H2B 1Z4
# Arrondissement                              Ahuntsic-Cartierville
# Classification                                           niveau 3
# Longitude                                              -73.661102
# Latitude                                                45.574862
# Name: 0, dtype: object

# %%
np.random.seed(1)  # For reproducible results

# %%
"""
Enter the sample size. The sample size is the number of locations you want to include in the route.
"""
sample_size = 50

# %%
data = data.sample(n=sample_size)

# %%
# Convert DataFrame to GeoDataFrame
gdf = gpd.GeoDataFrame(data, geometry=gpd.points_from_xy(data.Longitude, data.Latitude))

# Set the coordinate reference system (CRS) to WGS84 (epsg:4326)
gdf.crs = "EPSG:4326"

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))
gdf.to_crs(epsg=3857).plot(ax=ax, color='blue', marker='o', markersize=50)

# Add basemap
#ctx.add_basemap(ax, source=ctx.providers.Stamen.TonerLite)

# Show the plot
plt.show()

# %%
def geographic_to_cartesian(row):
    # Convert latitude and longitude from degrees to radians
    lat = row['Latitude']
    lon = row['Longitude']
    lat, lon = map(math.radians, [lat, lon])

    # Earth radius in meters
    R = 6378

    # Convert to Cartesian coordinates
    x = R * math.cos(lat) * math.cos(lon)
    y = R * math.cos(lat) * math.sin(lon)
    z = R * math.sin(lat)

    return x, y, z

# %%
data['x'], data['y'], data['z']  = zip(*data.apply(geographic_to_cartesian, axis=1))

# %%
data
# Out:
#         ID              Famille                        Catégorie  \
# 1613  1734       Service public                 Service de santé
# 1710  1841  Récréatif / sportif        Parc et autre espace vert
# 2906  3134  Récréatif / sportif        Parc et autre espace vert
# 2087  2279       Service public                        Transport
# 2380  2589             Culturel                       Art public
# 1273  1349  Récréatif / sportif        Parc et autre espace vert
# 584    622             Culturel                Lieu de diffusion
# 3076  3308       Service public                        Transport
# 2355  2562             Culturel       Bâtiment et lieu d'intérêt
# 3011  3243             Culturel                Lieu de diffusion
# 535    573  Récréatif / sportif        Parc et autre espace vert
# 1336  1417  Récréatif / sportif        Parc et autre espace vert
# 933    993  Récréatif / sportif         Équipement communautaire
# 2541  2755           Commercial                      Hébergement
# 1856  2020  Récréatif / sportif        Parc et autre espace vert
# 1987  2167             Culturel                       Art public
# 3110  3342  Récréatif / sportif        Parc et autre espace vert
# 1128  1191  Récréatif / sportif  Équipement sportif et récréatif
# 98     100       Service public           Établissement scolaire
# 1365  1450       Service public           Établissement scolaire
# 2231  2429             Culturel                     Bibliothèque
# 3141  3373  Récréatif / sportif  Équipement sportif et récréatif
# 1401  1503  Récréatif / sportif         Équipement communautaire
# 75      77       Service public                        Transport
# 2508  2721  Récréatif / sportif              Attrait touristique
# 2772  2990       Service public                Service d'urgence
# 1684  1811             Culturel              Circuit et parcours
# 1760  1894       Service public           Établissement scolaire
# 1783  1940       Service public                Service d'urgence
# 713    759  Récréatif / sportif        Parc et autre espace vert
# 2470  2682           Commercial                      Hébergement
# 521    559  Récréatif / sportif        Parc et autre espace vert
# 13      14  Récréatif / sportif        Parc et autre espace vert
# 1680  1806       Service public                Service d'urgence
# 2664  2880           Commercial        Regroupement de commerces
# 2872  3097       Service public           Établissement scolaire
# 2878  3103       Service public           Établissement scolaire
# 3019  3251       Service public                        Transport
# 3122  3354  Récréatif / sportif        Parc et autre espace vert
# 7        8  Récréatif / sportif        Parc et autre espace vert
# 1727  1858  Récréatif / sportif        Parc et autre espace vert
# 600    640       Service public                Service d'urgence
# 2191  2389  Récréatif / sportif              Attrait touristique
# 394    425  Récréatif / sportif        Parc et autre espace vert
# 1708  1839  Récréatif / sportif        Parc et autre espace vert
# 2828  3050  Récréatif / sportif           Établissement scolaire
# 2467  2679           Commercial                      Hébergement
# 1577  1687  Récréatif / sportif        Parc et autre espace vert
# 1153  1216  Récréatif / sportif        Parc et autre espace vert
# 1223  1294  Récréatif / sportif        Parc et autre espace vert
#
#                                            Nom français  \
# 1613                           CLSC de La Petite-Patrie
# 1710                               Parc Isaac-Abrabanel
# 2906                 Jardin communautaire Le Goupillier
# 2087                                             20-428
# 2380                   Daudelin, Charles, Mastodo, 1984
# 1273                                   Parc d'À-Ma-Baie
# 584   Centre culturel et communautaire Henri-Lemieux...
# 3076                                Gare Montréal-Ouest
# 2355                               Chalet du mont Royal
# 3011                Centre Design et Impression Textile
# 535                                   Parc J.O.R.-Leduc
# 1336                                  Parc Rita-Marceau
# 933                        Maison des jeunes La Galerie
# 2541                                    LHotel Montréal
# 1856                               Parc Arthur-Therrien
# 1987  McEwen, John et Hilton-Moore, Marlene, After B...
# 3110                           Parc du Bassin-à-Gravier
# 1128               Piste d'athlétisme Lester B. Pearson
# 98                               École secondaire Duval
# 1365                              École Murielle-Dumont
# 2231                                BAnQ Vieux-Montréal
# 3141                              Piscine Saint-Georges
# 1401           Centre récréatif de Rivière-des-Prairies
# 75                                Pôle Secteur Chabanel
# 2508                   L’Observatoire Place Ville Marie
# 2772                                          Caserne 5
# 1684                                        6ème avenue
# 1760                   École Beau-Séjour (édifice nord)
# 1783                                         Caserne 73
# 713                    Jardin communautaire De Lorimier
# 2470                                     Hôtel St-Denis
# 521                                         Parc Boivin
# 13                                   Parc de Beauséjour
# 1680                                         Caserne 50
# 2664                                         Rue Bishop
# 2872      Centre John-F.-Kennedy Adult Education Center
# 2878                                     École Montcalm
# 3019                                 Métro De la Savane
# 3122                        Jardin collectif du citoyen
# 7                                  Parc Basile-Routhier
# 1727                             Parc Urgel-Archambault
# 600                                          Caserne 65
# 2191                                     Atrium Le 1000
# 394                                Parc Jonathan-Wilson
# 1708                                   Parc Hartenstein
# 2828  École Saint-Noël-Chabanel (pavillon des Bâtiss...
# 2467                      Hotel Quartier des spectacles
# 1577                          Parc Jean-et-Éva-Tremblay
# 1153                                         Parc Pilon
# 1223                                         Parc Canin
#
#                                            Nom court  \
# 1613                                             NaN
# 1710                                             NaN
# 2906                                             NaN
# 2087                                             NaN
# 2380                                         Mastodo
# 1273                                             NaN
# 584   Centre culturel et communautaire Henri-Lemieux
# 3076                                  Montréal-Ouest
# 2355                                             NaN
# 3011                                             NaN
# 535                                              NaN
# 1336                                             NaN
# 933                     Maison des jeunes La Galerie
# 2541                                             NaN
# 1856                                             NaN
# 1987                                     After Babel
# 3110                                             NaN
# 1128                                             NaN
# 98                                               NaN
# 1365                                             NaN
# 2231                                             NaN
# 3141                                             NaN
# 1401                                             NaN
# 75                                               NaN
# 2508                                             NaN
# 2772                                             NaN
# 1684                                             NaN
# 1760                        École Beau-Séjour (nord)
# 1783                                             NaN
# 713                                              NaN
# 2470                                             NaN
# 521                                              NaN
# 13                                               NaN
# 1680                                             NaN
# 2664                                             NaN
# 2872                                             NaN
# 2878                                             NaN
# 3019                                    De la Savane
# 3122                                             NaN
# 7                                                NaN
# 1727                                             NaN
# 600                                              NaN
# 2191                                             NaN
# 394                                              NaN
# 1708                                             NaN
# 2828          École Saint-Noël-Chabanel (Bâtisseurs)
# 2467                                             NaN
# 1577                                             NaN
# 1153                                             NaN
# 1223                                             NaN
#
#                                               Type Numéro  \
# 1613                                          CLSC   6520
# 1710                                          Parc
# 2906                          Jardin communautaire
# 2087                      Poste d'attente de taxis
# 2380                                    Art public
# 1273                                          Parc
# 584                    Lieu de diffusion municipal   7644
# 3076                                 Gare de train   7499
# 2355             Bâtiment historique / patrimonial   1196
# 394        niveau 2 -73.872055  45.500191  1241.797713 -4294.446744
# 1708       niveau 2 -73.691307  45.518055  1254.940620 -4289.146440
# 2828       niveau 4 -73.613535  45.579051  1259.394060 -4282.789009
# 2467       niveau 4 -73.564121  45.509768  1264.644830 -4286.981386
# 1577       niveau 3 -73.558754  45.551556  1264.106869 -4283.679060
# 1153       niveau 2 -73.642113  45.593910  1256.924999 -4282.282931
# 1223       niveau 3 -73.621414  45.519932  1260.129814 -4287.469382
#
#                 z
# 1613  4551.826767
# 1710  4548.784693
# 2906  4555.609966
# 2087  4548.604166
# 2380  4550.031437
# 1273  4549.475926
# 584   4543.697926
# 3076  4545.494336
# 2355  4549.419192
# 3011  4546.800695
# 535   4543.492003
# 1336  4549.460774
# 933   4547.540281
# 2541  4549.355650
# 1856  4546.456996
# 1987  4549.889738
# 3110  4548.247151
# 1128  4557.899150
# 98    4553.205504
# 1365  4549.619725
# 2231  4550.143739
# 3141  4561.093576
# 1401  4559.014093
# 75    4552.327007
# 2508  4549.236028
# 2772  4550.060420
# 1684  4553.260858
# 1760  4550.886695
# 1783  4550.091351
# 713   4551.936111
# 2470  4550.151276
# 521   4542.807707
# 13    4551.272553
# 1680  4554.329826
# 2664  4548.841760
# 2872  4553.812826
# 2878  4554.574677
# 3019  4549.140849
# 3122  4560.090440
# 7     4553.619109
# 1727  4547.666019
# 600   4543.323621
# 2191  4548.972656
# 394   4549.126246
# 1708  4550.519844
# 2828  4555.274844
# 2467  4549.873411
# 1577  4553.132057
# 1153  4556.432425
# 1223  4550.666231

# %%
def recenter_cartesian(value,minimum):
    return value - minimum

# %%
data['x'] = data.apply(lambda row : recenter_cartesian(row['x'],data['x'].min()), axis = 1)

# %%
data['y'] = data.apply(lambda row : recenter_cartesian(row['y'],data['y'].min()), axis = 1)

# %%
data['z'] = data.apply(lambda row : recenter_cartesian(row['z'],data['z'].min()), axis = 1)

# %%
data.loc[1613]
# Out:
# ID                                     1734
# Famille                      Service public
# Catégorie                  Service de santé
# Nom français       CLSC de La Petite-Patrie
# Nom court                               NaN
# Type                                   CLSC
# Numéro                                 6520
# rue                    Rue De Saint-Vallier
# Étage                                     0
# Bureau
# Ville                              Montréal
# Code postal                         H2S 2P7
# Arrondissement    Rosemont–La Petite-Patrie
# Classification                     niveau 3
# Longitude                        -73.605193
# Latitude                          45.534813
# x                                 19.212214
# y                                  9.417667
# z                                   9.01906
# Name: 1613, dtype: object

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(data['x'], data['y'], data['z'], c='b', marker='o')

ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
ax.set_zlabel('Z Axis')

plt.title('Cartesian Coordinates of the Places of Interest')
plt.show()

# %%
from matplotlib.animation import FuncAnimation
from matplotlib import rc

rc('animation', html='html5')

# Create a 3D scatter plot
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')

# Create the scatter plot
scatter = ax.scatter(data['x'], data['y'], data['z'], c='b', marker='o')

# Function to update the view when called
def update(num, scatter, ax):
    ax.view_init(elev=num, azim=num)

# Create an animation by rotating the view
ani = FuncAnimation(fig, update, frames=np.arange(0, 360, 2), fargs=(scatter, ax), interval=50)

# Display the animation
plt.show()

# %%
# Display the animation.
ani
# Out:
# <video width="720" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
coordinates = data[['x', 'y', 'z']].to_numpy()

# %%
coordinates
# Out:
# array([[19.21221358,  9.41766739,  9.01906008],
#        [13.90467205,  4.63236669,  5.97698591],
#        [16.55397997, 12.65714824, 12.8022593 ],
#        [22.47853134,  6.9593453 ,  5.7964587 ],
#        [23.50755352,  8.77731816,  7.22373014],
#        [ 6.59478586,  3.23242158,  6.66821928],
#        [22.36601323,  1.72828507,  0.89021933],
#        [18.28250679,  2.42939151,  2.68662882],
#        [21.22832087,  7.45552966,  6.61148453],
#        [22.10778505,  4.93803523,  3.99298841],
#        [19.5425095 ,  0.68012081,  0.68429571],
#        [ 1.38173541,  1.70356317,  6.65306716],
#        [22.31254836,  5.78228108,  4.73257419],
#        [23.40106602,  8.02869137,  6.54794301],
#        [24.0499311 ,  5.14638697,  3.64928929],
#        [22.60867204,  8.36170063,  7.08203115],
#        [23.35794914,  6.84003977,  5.43944395],
#        [16.47524417, 15.07034312, 15.09144254],
#        [14.02633762,  9.35950829, 10.39779744],
#        [ 2.66986759,  2.24517371,  6.81201803],
#        [23.46933526,  8.88524249,  7.33603164],
#        [24.94882375, 20.9765277 , 18.28586895],
#        [17.91007797, 16.68007052, 16.20638572],
#        [15.5055379 ,  8.86003545,  9.51930014],
#        [22.69458668,  7.69335145,  6.42832133],
#        [22.5903241 ,  8.5374429 ,  7.25271271],
#        [19.794796  , 11.11273223, 10.45315123],
#        [10.019499  ,  5.72617889,  8.07898825],
#        [14.26240223,  6.12276279,  7.28364406],
#        [21.3887632 , 10.17479364,  9.12840405],
#        [23.08103848,  8.77864711,  7.34356893],
#        [19.69131143,  0.        ,  0.        ],
#        [ 9.88319656,  6.0957932 ,  8.46484648],
#        [20.71171989, 12.51928174, 11.52211952],
#        [22.23343032,  7.13911299,  6.03405321],
#        [18.72791034, 11.38536546, 11.00511925],
#        [17.11131571, 11.71991608, 11.76696974],
#        [15.76038905,  5.55353446,  6.33314157],
#        [24.82899799, 19.8708655 , 17.28273303],
#        [13.68919672,  9.70015781, 10.81140178],
#        [ 8.24275723,  1.79426961,  4.85831221],
#        [20.067054  ,  0.65607733,  0.51591397],
#        [22.94127769,  7.48668662,  6.16494904],
#        [ 0.        ,  0.94934736,  6.31853945],
#        [13.1429072 ,  6.2496509 ,  7.71213751],
#        [17.59634727, 12.60708201, 12.46713713],
#        [22.84711674,  8.41470545,  7.06570384],
#        [22.30915662, 11.71703086, 10.32435039],
#        [15.12728656, 13.11316023, 13.62471831],
#        [18.33210108,  7.92670897,  7.85852443]])

# %%
# Greedy approach
def greedy_tsp(coordinates):
    remaining_locations = list(range(len(coordinates)))
    path = [remaining_locations.pop(0)] # Start from the first location
    while remaining_locations:
        current_location = path[-1]
        next_location = min(remaining_locations, key=lambda location: np.linalg.norm(coordinates[current_location] - coordinates[location]))
        path.append(next_location)
        remaining_locations.remove(next_location)
    return path

# %%
greedy_route = greedy_tsp(coordinates)

# %%
# Calculate the total distance of the travel route

# Calculate Euclidean distance between two locations
def distance(from_location, to_location):
    return np.linalg.norm(coordinates[from_location] - coordinates[to_location])

# Evaluate the total distance of the route
def evaluate(route):  
    distance_sum = sum(distance(route[i], route[i+1]) for i in range(len(route) - 1))
    distance_sum += distance(route[0], route[-1])  # Return to the starting location
    return distance_sum,

# %%
print("Route (Greedy Approach): ", greedy_route)
print("Route Distance (Greedy Approach): ", evaluate(greedy_route))
# Out:
# Route (Greedy Approach):  [0, 49, 8, 34, 3, 42, 24, 13, 46, 15, 25, 30, 20, 4, 16, 12, 9, 14, 6, 41, 10, 31, 7, 37, 28, 44, 1, 27, 32, 5, 40, 19, 11, 43, 18, 39, 23, 36, 45, 2, 48, 17, 22, 33, 26, 35, 29, 47, 38, 21]
# Route Distance (Greedy Approach):  (141.20365649882888,)

# %%
"""
Adjust the population size and the number of generations the genetic algorithm will evolve
"""
population_size = 500
generations = 500

# %%
from deap import base, creator, tools, algorithms

num_locations = len(coordinates)

# Set up DEAP
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

toolbox = base.Toolbox()
toolbox.register("indices", random.sample, range(num_locations), num_locations)
toolbox.register("individual", tools.initIterate, creator.Individual, toolbox.indices)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("mate", tools.cxOrdered)
toolbox.register("mutate", tools.mutShuffleIndexes, indpb=0.05)
toolbox.register("select", tools.selTournament, tournsize=3)
toolbox.register("evaluate", evaluate)

def main():
    pop = toolbox.population(n=population_size)
    hof = tools.HallOfFame(1)
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("avg", np.mean)
    stats.register("min", np.min)

    pop, log = algorithms.eaSimple(pop, toolbox, 0.7, 0.2, generations, stats=stats, halloffame=hof, verbose=True)

    return pop, log, hof

if __name__ == "__main__":
    pop, log, hof = main()
    best_route = hof[0]
    print(f"Best Route (Genetic Algorithm): {best_route}")
    print(f"Route Distance (Genetic Algorithm): {evaluate(best_route)[0]}")
# Out:
# C:\Users\tano_\anaconda3\lib\site-packages\deap\creator.py:185: RuntimeWarning: A class named 'FitnessMin' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# C:\Users\tano_\anaconda3\lib\site-packages\deap\creator.py:185: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# gen	nevals	avg    	min
# 0  	500   	530.667	439.955
# 1  	362   	509.715	399.73
# 2  	374   	496.469	399.73
# 3  	386   	481.963	390.59
# 4  	377   	471.926	400.658
# 5  	369   	463.678	392.106
# 6  	385   	455.22 	331.299
# 7  	401   	448.511	377.56
# 8  	378   	440.443	362.453
# 9  	371   	430.938	339.527
# 10 	418   	423.912	339.081
# 11 	384   	418.435	345.345
# 12 	365   	409.471	342.478
# 13 	368   	404.32 	334.282
# 14 	394   	397.978	290.313
# 15 	383   	393.132	295.321
# 16 	385   	385.625	295.321
# 17 	378   	380.532	293.724
# 18 	367   	369.967	295.321
# 19 	366   	363.327	304.128
# 20 	376   	357.871	291.854
# 21 	379   	354.693	294.235
# 22 	392   	351.544	283.838
# 23 	369   	345.604	281.467
# 24 	379   	341.224	268.562
# 25 	384   	337.037	259.191
# 26 	355   	330.676	259.191
# 27 	372   	324.167	238.991
# 28 	374   	318.456	254.053
# 29 	383   	314.941	248.382
# 30 	364   	308.644	246.428
# 31 	369   	306.317	249.001
# 32 	374   	301.723	244.865
# 33 	359   	300.009	241.966
# 34 	394   	299.282	231.962
# 35 	373   	298.113	231.962
# 36 	374   	295.43 	234.571
# 37 	381   	294.819	232.662
# 38 	370   	292.254	230.32
# 39 	360   	288.362	226.673
# 40 	360   	285.664	228.742
# 41 	370   	281.422	216.441
# 42 	381   	281.77 	213.458
# 43 	378   	279.924	220.571
# 44 	375   	278.944	222.848
# 45 	378   	275.161	218.787
# 46 	377   	274.315	225.471
# 47 	391   	273.852	225.471
# 48 	398   	273.74 	218.751
# 49 	375   	271.586	220.319
# 50 	381   	268.448	223.703
# 51 	393   	269.443	223.385
# 52 	367   	271.704	220.506
# 53 	372   	268.282	220.506
# 54 	383   	268.644	220.506
# 55 	392   	266.984	206.841
# 56 	387   	268.831	206.841
# 57 	398   	266.429	214.802
# 58 	398   	266.742	208.678
# 59 	367   	263.418	205.059
# 60 	369   	262.595	208.231
# 61 	395   	261.687	206.507
# 62 	358   	256.75 	206.507
# 63 	382   	256.787	208.678
# 64 	376   	255.935	203.704
# 65 	371   	256.691	203.704
# 66 	364   	251.145	208.561
# 67 	370   	255.223	200.182
# 68 	373   	252.815	200.182
# 69 	385   	251.711	197.8
# 70 	379   	254.098	198.933
# 71 	400   	256.343	193.413
# 72 	381   	254.412	189.389
# 73 	396   	254.97 	197.465
# 74 	376   	252.12 	197.465
# 75 	360   	251.092	195.293
# 76 	377   	250.355	201.541
# 77 	382   	249.548	192.988
# 78 	378   	247.132	198.248
# 79 	383   	243.529	198.248
# 80 	378   	243.912	188.746
# 81 	379   	242.647	188.746
# 82 	367   	242.778	189.381
# 83 	377   	239.668	189.381
# 84 	370   	236.014	190.971
# 85 	370   	236.442	181.524
# 86 	368   	235.406	181.524
# 87 	374   	229.515	182.018
# 88 	370   	234.645	183.915
# 89 	385   	234.063	183.915
# 90 	394   	231.488	183.086
# 91 	370   	228.781	183.086
# 92 	384   	229.1  	183.086
# 93 	342   	224.975	181.861
# 94 	398   	224.817	181.861
# 95 	391   	222.576	182.05
# 96 	366   	218.368	177.463
# 97 	384   	216.301	177.463
# 98 	392   	217.071	176.794
# 99 	386   	216.025	173.147
# 100	391   	215.268	175.67
# 101	362   	215.682	175.67
# 102	405   	212.995	172.725
# 103	370   	213.085	167.011
# 104	384   	212.244	167.011
# 105	386   	212.146	172.325
# 106	370   	213.768	169.682
# 107	386   	213.181	172.307
# 108	391   	213.084	166.031
# 109	377   	210.52 	170.183
# 110	384   	210.351	166.142
# 111	372   	210.166	166.142
# 112	375   	212.367	166.142
# 113	392   	211.608	167.149
# 114	374   	211.621	167.149
# 115	396   	212.403	167.149
# 116	369   	210.475	167.149
# 117	353   	207.238	167.149
# 118	399   	209.943	167.149
# 119	390   	208.63 	167.128
# 120	365   	204.623	156.78
# 121	360   	204.849	156.78
# 122	378   	204.041	156.78
# 123	367   	204.235	156.78
# 124	369   	203.152	156.78
# 125	381   	200.676	155.79
# 126	379   	201.653	156.78
# 127	377   	199.685	156.78
# 128	366   	198.86 	156.78
# 129	386   	198.425	156.78
# 130	390   	199.82 	156.78
# 131	378   	197.654	157.528
# 132	383   	197.2  	148.439
# 133	391   	200.265	152.841
# 134	373   	197.546	151.848
# 135	392   	194.162	152.841
# 136	368   	186.629	149.041
# 137	382   	188.407	148.396
# 138	389   	189.456	148.396
# 237	379   	150.551	136.127
# 238	381   	150.299	136.127
# 239	410   	151.59 	136.127
# 240	376   	151.872	136.127
# 241	395   	149.528	136.127
# 242	355   	150.547	136.127
# 243	386   	148.423	135.72
# 244	383   	151.454	135.72
# 245	376   	150.111	135.423
# 246	391   	151.703	135.423
# 247	396   	150.959	135.423
# 248	370   	151.557	135.423
# 249	388   	150.287	135.226
# 250	382   	152.252	135.226
# 251	379   	150.011	135.163
# 252	393   	153.664	135.163
# 253	386   	150.34 	135.163
# 254	356   	148.446	135.163
# 255	377   	149.706	134.88
# 256	380   	152.136	135.163
# 257	385   	151.259	135.163
# 258	381   	149.293	135.163
# 259	378   	151.882	135.163
# 260	388   	150.193	135.163
# 261	387   	148.477	135.163
# 262	402   	150.925	135.163
# 263	379   	149.778	135.163
# 264	385   	151.547	134.882
# 265	398   	151.927	135.163
# 266	384   	150.856	135.163
# 267	382   	149.11 	134.817
# 268	375   	149.945	134.817
# 269	401   	147.542	134.817
# 270	360   	150.033	134.817
# 271	375   	148.757	134.817
# 272	399   	150.342	134.817
# 273	402   	151.445	134.5
# 274	378   	150.018	134.499
# 275	367   	150.471	134.499
# 276	400   	149.726	134.499
# 277	372   	149.833	134.499
# 278	377   	149.911	134.499
# 279	379   	152.249	134.183
# 280	385   	150.915	134.183
# 281	388   	151.335	133.836
# 282	357   	148.671	133.836
# 283	383   	151.653	133.836
# 284	389   	151.938	133.836
# 285	381   	152.954	133.836
# 286	372   	151.591	133.836
# 287	359   	150.98 	133.836
# 288	391   	149.196	133.836
# 289	405   	148.873	133.836
# 290	386   	146.637	133.836
# 291	384   	150.96 	133.836
# 292	365   	148.724	133.836
# 293	373   	146.9  	133.836
# 294	375   	150.796	133.836
# 295	372   	149.291	133.836
# 296	366   	149.926	133.836
# 297	381   	146.93 	133.836
# 298	379   	144.125	133.836
# 299	395   	148.114	132.701
# 300	383   	147.589	132.701
# 301	364   	146.559	132.701
# 302	368   	148.957	132.701
# 303	394   	147.609	132.701
# 304	381   	151.89 	132.701
# 305	354   	147.849	132.701
# 306	373   	149.419	132.701
# 307	389   	148.161	132.701
# 308	385   	148.877	132.701
# 309	385   	146.939	132.701
# 310	390   	146.436	132.591
# 311	384   	150.624	132.591
# 312	400   	147.847	132.591
# 313	382   	148.221	132.591
# 314	394   	145.858	132.591
# 315	386   	147.495	132.591
# 316	366   	148.778	132.591
# 317	393   	147.22 	132.576
# 318	392   	148.638	132.576
# 319	380   	147.726	132.576
# 320	378   	147.531	132.576
# 321	375   	147.659	132.576
# 322	390   	145.788	132.576
# 323	373   	149.304	132.576
# 324	391   	146.53 	132.576
# 325	396   	145.361	132.576
# 326	385   	151.653	132.576
# 327	367   	149.42 	132.576
# 328	377   	147.114	132.537
# 329	368   	145.284	132.537
# 330	374   	146.681	132.537
# 331	373   	148.866	132.537
# 332	381   	147.615	132.537
# 333	395   	150.19 	132.537
# 334	402   	145.311	132.537
# 335	389   	143.559	132.537
# 434	383   	144.434	130.764
# 435	384   	143.044	130.764
# 436	384   	145.099	130.764
# 437	381   	145.235	130.764
# 438	396   	144.726	130.764
# 439	392   	150.511	130.764
# 440	373   	147.975	130.522
# 441	376   	147.503	130.764
# 442	389   	145    	130.522
# 443	387   	144.887	130.522
# 444	381   	146.602	130.522
# 445	396   	146.726	130.522
# 446	379   	147.976	130.522
# 447	364   	146.571	130.522
# 448	383   	145.746	130.522
# 449	364   	150.396	130.522
# 450	393   	143.162	130.522
# 451	387   	145.964	130.522
# 452	383   	145.185	130.522
# 453	405   	145.138	130.522
# 454	389   	144.418	130.522
# 455	377   	147.578	130.522
# 456	368   	143.952	130.522
# 457	374   	144.426	130.522
# 458	382   	143.775	130.522
# 459	377   	145.732	130.522
# 460	380   	147.97 	130.522
# 461	389   	144.805	130.264
# 462	405   	141.048	130.264
# 463	365   	144.769	130.264
# 464	363   	143.911	130.264
# 465	361   	143.407	130.264
# 466	386   	145.558	130.264
# 467	399   	147.777	130.264
# 468	388   	147.524	130.264
# 469	390   	146.132	130.264
# 470	394   	143.472	130.264
# 471	384   	144.484	130.264
# 472	361   	146.227	130.264
# 473	370   	144.394	130.264
# 474	377   	144.387	130.264
# 475	357   	145.666	130.264
# 476	372   	147.095	130.264
# 477	366   	145.777	130.264
# 478	361   	144.667	130.264
# 479	351   	144.263	130.264
# 480	397   	146.645	130.264
# 481	364   	146.158	130.264
# 482	370   	144.827	130.264
# 483	378   	145.77 	130.264
# 484	388   	144.118	130.264
# 485	384   	141.857	130.264
# 486	400   	143.035	130.264
# 487	383   	143.145	130.264
# 488	371   	145.125	130.264
# 489	396   	147.584	130.264
# 490	398   	145.871	130.264
# 491	391   	145.663	130.264
# 492	375   	147.074	130.264
# 493	385   	145.391	130.264
# 494	382   	145.378	130.264
# 495	378   	145.491	130.264
# 496	386   	143.737	130.264
# 497	385   	144.341	130.264
# 498	392   	143.142	130.264
# 499	371   	145.323	130.264
# 500	361   	145.487	130.264
# Best Route (Genetic Algorithm): [34, 3, 42, 24, 15, 25, 46, 30, 20, 4, 13, 16, 12, 9, 14, 6, 41, 31, 10, 7, 37, 28, 44, 32, 27, 5, 19, 11, 43, 40, 1, 33, 47, 29, 0, 26, 35, 36, 2, 45, 38, 21, 22, 17, 48, 39, 18, 23, 49, 8]
# Route Distance (Genetic Algorithm): 130.26376618188053

# %% [markdown]
# ## Assignment
#
# ### Conceptual Option
#
# Identify a problem or situation that you are interested in that could be optimized using genetic algorithms. Explore the existing literature published on Google Scholar and the McGill Library. Review in detail two research articles published on the topic. Prepare a report (2-3 page Word document) that summarizes the main ideas and findings of the selected articles in your own words and your insights. Reference the consulted sources using the APA format.
#
# ### Hands-on Option
#
# Select a sample size, and adjust (increase and decrease) the population size and number of generations using the provided code. Compare the results against the greedy approach of each scenario. Explain the results obtained, taking into account the process genetic algorithms follow. Prepare a report (1-2 page Word document) that summarizes your results and insights. Reference the consulted sources using the APA format.
