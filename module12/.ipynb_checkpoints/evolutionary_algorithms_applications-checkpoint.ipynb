# %% [markdown]
# # Applications of Evolutionary Algorithms
#
# ## Introduction
#
# In this module, we will apply evolutionary algorithms to solve routing problems. Please watch the following video about the travelling salesperson problem in preparation for the module's interaction portion.

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/Ov0EetgMws4" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/Ov0EetgMws4" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>

# %% [markdown]
# ## Concepts
#
# You will find a list of important concepts we will review in the module below.
#
# - Traveling salesperson problem
# - Optimization
# - Routes

# %% [markdown]
# ## Interaction

# %%
import numpy as np
import random
import pandas as pd
import math
import geopandas as gpd
from shapely.geometry import Point
import matplotlib.pyplot as plt
import contextily as ctx

# %%
data = pd.read_excel('points_of_interest.xlsx', sheet_name='points_of_interest') # Load the data into a Pandas Dataframe

# %%
data
# Out:
#         ID              Famille                  Catégorie  \
# 0        1             Culturel     Établissement culturel
# 1        2             Culturel     Établissement culturel
# 2        3           Commercial  Regroupement de commerces
# 3        4             Culturel     Établissement culturel
# 4        5  Récréatif / sportif  Parc et autre espace vert
# ...    ...                  ...                        ...
# 3226  3458  Récréatif / sportif   Équipement communautaire
# 3227  3459           Commercial  Regroupement de commerces
# 3228  3460           Commercial  Regroupement de commerces
# 3229  3461           Commercial  Regroupement de commerces
# 3230  3462           Commercial  Regroupement de commerces
#
#                           Nom français Nom court  \
# 0                    Maison du Meunier       NaN
# 1                   Maison du Pressoir       NaN
# 2                       Marché Central       NaN
# 3     Musée des Sœurs de la Providence       NaN
# 4                        Parc Ahuntsic       NaN
# ...                                ...       ...
# 3226                   Centre Appleton       NaN
# 3227             Les Galleries d'Anjou       NaN
# 3228                    Place Bourassa       NaN
# 3229                       Place Vertu       NaN
# 3230               Carrefour Angrignon       NaN
#
#                                                  Type  Numéro  \
# 0     Musée et centre d'interprétation / d'exposition   10897
# 1     Musée et centre d'interprétation / d'exposition   10865
# 2                                   Centre commercial    9187
# 3     Musée et centre d'interprétation / d'exposition  12055
# 4                                                Parc
# ...                                               ...     ...
# 3226     Organisme communautaire et centre de loisirs    6585
# 3227                                Centre commercial    7999
# 3228                                Centre commercial    6000
# 3229                                Centre commercial    3131
# 3230                                Centre commercial    7077
#
#                                   rue  Étage Bureau     Ville Code postal  \
# 0                         Rue du Pont      0         Montréal     H2B 1Z4
# 1                     Rue du Pressoir      0         Montréal     H2B 2L1
# 2               Boulevard de l'Acadie      0         Montréal     H4N 3K1
# 3                          Rue Grenet      0         Montréal     H4J 2J5
# 4                                          0         Montréal     H3L 2E5
# ...                               ...    ...    ...       ...         ...
# 3226     Chemin de la Côte-des-Neiges      0         Montréal     H3S 2A5
# 3227  Boulevard des Galeries d'Anjou,      0         Montréal     H1M 1W9
# 3228         Boulevard Henri-Bourassa      0         Montréal     H1G 2T6
# 3229       Boulevard de la Côte-Vertu      0         Montréal     H4R 1Y8
# 3230                 Boulevard Newman      0         Montréal     H8N 1X1
#
#                            Arrondissement Classification  Longitude   Latitude
# 0                   Ahuntsic-Cartierville       niveau 3 -73.661102  45.574862
# 1                   Ahuntsic-Cartierville       niveau 3 -73.659553  45.575970
# 2                   Ahuntsic-Cartierville       niveau 1 -73.654956  45.534023
# 3                   Ahuntsic-Cartierville       niveau 3 -73.713635  45.529374
# 4                   Ahuntsic-Cartierville       niveau 2 -73.664710  45.555801
# ...                                   ...            ...        ...        ...
# 3226  Côte-des-Neiges–Notre-Dame-de-Grâce       niveau 3 -73.635287  45.502481
# 3227                                Anjou       niveau 1 -73.564512  45.600636
# 3228                        Montréal-Nord       niveau 2 -73.616778  45.606041
# 3229                        Saint-Laurent       niveau 1 -73.706614  45.498756
# 3230                              LaSalle       niveau 1 -73.615478  45.447801
#
# [3231 rows x 16 columns]

# %%
data['Longitude']
# Out:
# 0      -73.661102
# 1      -73.659553
# 2      -73.654956
# 3      -73.713635
# 4      -73.664710
#           ...
# 3226   -73.635287
# 3227   -73.564512
# 3228   -73.616778
# 3229   -73.706614
# 3230   -73.615478
# Name: Longitude, Length: 3231, dtype: float64

# %%
data.Longitude
# Out:
# 0      -73.661102
# 1      -73.659553
# 2      -73.654956
# 3      -73.713635
# 4      -73.664710
#           ...
# 3226   -73.635287
# 3227   -73.564512
# 3228   -73.616778
# 3229   -73.706614
# 3230   -73.615478
# Name: Longitude, Length: 3231, dtype: float64

# %%
data.loc[0] # Access the first row via its primary label
# Out:
# ID                                                              1
# Famille                                                  Culturel
# Catégorie                                  Établissement culturel
# Nom français                                    Maison du Meunier
# Nom court                                                     NaN
# Type              Musée et centre d'interprétation / d'exposition
# Numéro                                                      10897
# rue                                                   Rue du Pont
# Étage                                                           0
# Bureau
# Ville                                                    Montréal
# Code postal                                               H2B 1Z4
# Arrondissement                              Ahuntsic-Cartierville
# Classification                                           niveau 3
# Longitude                                              -73.661102
# Latitude                                                45.574862
# Name: 0, dtype: object

# %%
np.random.seed(1)  # For reproducible results

# %%
data = data.sample(n=50)

# %%
# Convert DataFrame to GeoDataFrame
gdf = gpd.GeoDataFrame(data, geometry=gpd.points_from_xy(data.Longitude, data.Latitude))

# Set the coordinate reference system (CRS) to WGS84 (epsg:4326)
gdf.crs = "EPSG:4326"

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))
gdf.to_crs(epsg=3857).plot(ax=ax, color='blue', marker='o', markersize=50)

# Add basemap
#ctx.add_basemap(ax, source=ctx.providers.Stamen.TonerLite)

# Show the plot
plt.show()

# %%
def geographic_to_cartesian(row):
    # Convert latitude and longitude from degrees to radians
    
    lat = row['Longitude']
    lon = row['Latitude']
    lat, lon = map(math.radians, [lat, lon])

    # Earth radius in kilometers
    R = 6371

    # Convert to Cartesian coordinates
    x = R * math.cos(lat) * math.cos(lon)
    y = R * math.cos(lat) * math.sin(lon)
    z = R * math.sin(lat)

    return x, y, z

# %%
data['x'], data['y'], data['z']  = zip(*data.apply(geographic_to_cartesian, axis=1))

# %%
data
# Out:
#         ID              Famille                        Catégorie  \
# 1613  1734       Service public                 Service de santé
# 1710  1841  Récréatif / sportif        Parc et autre espace vert
# 2906  3134  Récréatif / sportif        Parc et autre espace vert
# 2087  2279       Service public                        Transport
# 2380  2589             Culturel                       Art public
# 1273  1349  Récréatif / sportif        Parc et autre espace vert
# 584    622             Culturel                Lieu de diffusion
# 3076  3308       Service public                        Transport
# 2355  2562             Culturel       Bâtiment et lieu d'intérêt
# 3011  3243             Culturel                Lieu de diffusion
# 535    573  Récréatif / sportif        Parc et autre espace vert
# 1336  1417  Récréatif / sportif        Parc et autre espace vert
# 933    993  Récréatif / sportif         Équipement communautaire
# 2541  2755           Commercial                      Hébergement
# 1856  2020  Récréatif / sportif        Parc et autre espace vert
# 1987  2167             Culturel                       Art public
# 3110  3342  Récréatif / sportif        Parc et autre espace vert
# 1128  1191  Récréatif / sportif  Équipement sportif et récréatif
# 98     100       Service public           Établissement scolaire
# 1365  1450       Service public           Établissement scolaire
# 2231  2429             Culturel                     Bibliothèque
# 3141  3373  Récréatif / sportif  Équipement sportif et récréatif
# 1401  1503  Récréatif / sportif         Équipement communautaire
# 75      77       Service public                        Transport
# 2508  2721  Récréatif / sportif              Attrait touristique
# 2772  2990       Service public                Service d'urgence
# 1684  1811             Culturel              Circuit et parcours
# 1760  1894       Service public           Établissement scolaire
# 1783  1940       Service public                Service d'urgence
# 713    759  Récréatif / sportif        Parc et autre espace vert
# 2470  2682           Commercial                      Hébergement
# 521    559  Récréatif / sportif        Parc et autre espace vert
# 13      14  Récréatif / sportif        Parc et autre espace vert
# 1680  1806       Service public                Service d'urgence
# 2664  2880           Commercial        Regroupement de commerces
# 2872  3097       Service public           Établissement scolaire
# 2878  3103       Service public           Établissement scolaire
# 3019  3251       Service public                        Transport
# 3122  3354  Récréatif / sportif        Parc et autre espace vert
# 7        8  Récréatif / sportif        Parc et autre espace vert
# 1727  1858  Récréatif / sportif        Parc et autre espace vert
# 600    640       Service public                Service d'urgence
# 2191  2389  Récréatif / sportif              Attrait touristique
# 394    425  Récréatif / sportif        Parc et autre espace vert
# 1708  1839  Récréatif / sportif        Parc et autre espace vert
# 2828  3050  Récréatif / sportif           Établissement scolaire
# 2467  2679           Commercial                      Hébergement
# 1577  1687  Récréatif / sportif        Parc et autre espace vert
# 1153  1216  Récréatif / sportif        Parc et autre espace vert
# 1223  1294  Récréatif / sportif        Parc et autre espace vert
#
#                                            Nom français  \
# 1613                           CLSC de La Petite-Patrie
# 1710                               Parc Isaac-Abrabanel
# 2906                 Jardin communautaire Le Goupillier
# 2087                                             20-428
# 2380                   Daudelin, Charles, Mastodo, 1984
# 1273                                   Parc d'À-Ma-Baie
# 584   Centre culturel et communautaire Henri-Lemieux...
# 3076                                Gare Montréal-Ouest
# 2355                               Chalet du mont Royal
# 3011                Centre Design et Impression Textile
# 535                                   Parc J.O.R.-Leduc
# 1336                                  Parc Rita-Marceau
# 933                        Maison des jeunes La Galerie
# 2541                                    LHotel Montréal
# 1856                               Parc Arthur-Therrien
# 1987  McEwen, John et Hilton-Moore, Marlene, After B...
# 3110                           Parc du Bassin-à-Gravier
# 1128               Piste d'athlétisme Lester B. Pearson
# 98                               École secondaire Duval
# 1365                              École Murielle-Dumont
# 2231                                BAnQ Vieux-Montréal
# 3141                              Piscine Saint-Georges
# 1401           Centre récréatif de Rivière-des-Prairies
# 75                                Pôle Secteur Chabanel
# 2508                   L’Observatoire Place Ville Marie
# 2772                                          Caserne 5
# 1684                                        6ème avenue
# 1760                   École Beau-Séjour (édifice nord)
# 1783                                         Caserne 73
# 713                    Jardin communautaire De Lorimier
# 2470                                     Hôtel St-Denis
# 521                                         Parc Boivin
# 13                                   Parc de Beauséjour
# 1680                                         Caserne 50
# 2664                                         Rue Bishop
# 2872      Centre John-F.-Kennedy Adult Education Center
# 2878                                     École Montcalm
# 3019                                 Métro De la Savane
# 3122                        Jardin collectif du citoyen
# 7                                  Parc Basile-Routhier
# 1727                             Parc Urgel-Archambault
# 600                                          Caserne 65
# 2191                                     Atrium Le 1000
# 394                                Parc Jonathan-Wilson
# 1708                                   Parc Hartenstein
# 2828  École Saint-Noël-Chabanel (pavillon des Bâtiss...
# 2467                      Hotel Quartier des spectacles
# 1577                          Parc Jean-et-Éva-Tremblay
# 1153                                         Parc Pilon
# 1223                                         Parc Canin
#
#                                            Nom court  \
# 1613                                             NaN
# 1710                                             NaN
# 2906                                             NaN
# 2087                                             NaN
# 2380                                         Mastodo
# 1273                                             NaN
# 584   Centre culturel et communautaire Henri-Lemieux
# 3076                                  Montréal-Ouest
# 2355                                             NaN
# 3011                                             NaN
# 535                                              NaN
# 1336                                             NaN
# 933                     Maison des jeunes La Galerie
# 2541                                             NaN
# 1856                                             NaN
# 1987                                     After Babel
# 3110                                             NaN
# 1128                                             NaN
# 98                                               NaN
# 1365                                             NaN
# 2231                                             NaN
# 3141                                             NaN
# 1401                                             NaN
# 75                                               NaN
# 2508                                             NaN
# 2772                                             NaN
# 1684                                             NaN
# 1760                        École Beau-Séjour (nord)
# 1783                                             NaN
# 713                                              NaN
# 2470                                             NaN
# 521                                              NaN
# 13                                               NaN
# 1680                                             NaN
# 2664                                             NaN
# 2872                                             NaN
# 2878                                             NaN
# 3019                                    De la Savane
# 3122                                             NaN
# 7                                                NaN
# 1727                                             NaN
# 600                                              NaN
# 2191                                             NaN
# 394                                              NaN
# 1708                                             NaN
# 2828          École Saint-Noël-Chabanel (Bâtisseurs)
# 2467                                             NaN
# 1577                                             NaN
# 1153                                             NaN
# 1223                                             NaN
#
#                                               Type Numéro  \
# 1613                                          CLSC   6520
# 1710                                          Parc
# 2906                          Jardin communautaire
# 2087                      Poste d'attente de taxis
# 2380                                    Art public
# 1273                                          Parc
# 584                    Lieu de diffusion municipal   7644
# 3076                                 Gare de train   7499
# 2355             Bâtiment historique / patrimonial   1196
# 3011                                 Galerie d'art   4710
# 535                                           Parc
# 1336                                          Parc
# 933   Organisme communautaire et centre de loisirs   3570
# 2541                                         Hôtel    262
# 1856                                          Parc   3750
# 1987                                    Art public
# 3110                                          Parc
# 1577       niveau 3 -73.558754  45.551556  1262.719483  1287.267595
# 1153       niveau 2 -73.642113  45.593910  1255.545496  1281.848272
# 1223       niveau 3 -73.621414  45.519932  1258.746793  1281.801688
#
#                 z
# 1613 -6111.952350
# 1710 -6114.537307
# 2906 -6112.610922
# 2087 -6110.970196
# 2380 -6110.364777
# 1273 -6117.494800
# 584  -6111.608652
# 3076 -6113.102362
# 2355 -6111.396783
# 3011 -6111.343530
# 535  -6112.815129
# 1336 -6119.652724
# 933  -6111.168388
# 2541 -6110.491483
# 1856 -6110.569462
# 1987 -6110.759999
# 3110 -6110.643815
# 1128 -6112.367419
# 98   -6113.958240
# 1365 -6119.102249
# 2231 -6110.367239
# 3141 -6108.404733
# 1401 -6111.629454
# 75   -6113.445052
# 2508 -6110.803001
# 2772 -6110.747048
# 1684 -6111.534517
# 1760 -6115.905666
# 1783 -6114.232156
# 713  -6111.025050
# 2470 -6110.529681
# 521  -6112.834732
# 13   -6115.916571
# 1680 -6111.019609
# 2664 -6111.044445
# 2872 -6111.915793
# 2878 -6112.502091
# 3019 -6113.720185
# 3122 -6108.578882
# 7    -6114.049593
# 1727 -6117.024782
# 600  -6112.615955
# 2191 -6110.731178
# 394  -6120.261553
# 1708 -6114.648150
# 2828 -6112.214094
# 2467 -6110.661723
# 1577 -6110.492832
# 1153 -6113.109807
# 1223 -6112.461202

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(data['x'], data['y'], data['z'], c='b', marker='o')

ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
ax.set_zlabel('Z Axis')

plt.title('3D Scatter Plot')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.animation import FuncAnimation
from matplotlib import rc

rc('animation', html='html5')

# Generate some random data for demonstration
np.random.seed(42)
n_points = 100
x = np.random.rand(n_points)
y = np.random.rand(n_points)
z = np.random.rand(n_points)

# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Create the scatter plot
scatter = ax.scatter(data['x'], data['y'], data['z'], c='b', marker='o')

# Function to update the view when called
def update(num, scatter, ax):
    ax.view_init(elev=num, azim=num)

# Create an animation by rotating the view
ani = FuncAnimation(fig, update, frames=np.arange(0, 360, 2), fargs=(scatter, ax), interval=50)

# Display the animation
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.animation import FuncAnimation
from matplotlib import rc


# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Create the scatter plot
scatter = ax.scatter(data['x'], data['y'], data['z'], c='b', marker='o')

# Function to update the view when called
def update(num, scatter, ax):
    ax.view_init(elev=num, azim=num)

# Create an animation by rotating the view
ani = FuncAnimation(fig, update, frames=np.arange(0, 360, 2), fargs=(scatter, ax), interval=50)

# Save the animation as a GIF
ani.save("rotation_animation.gif", writer="pillow")

# Display the animation
plt.show()

# %%
coordinates = data[['x', 'y','z']].to_numpy()

# %%
coordinates
# Out:
# array([[ 1259.6259393 ,  1283.36353442, -6111.95235024],
#        [ 1254.32422292,  1276.22304904, -6114.53730653],
#        [ 1256.97062316,  1282.83029554, -6112.61092213],
#        [ 1262.8886722 ,  1284.83324205, -6110.97019644],
#        [ 1263.916565  ,  1286.7005126 , -6110.36477697],
#        [ 1247.02235949,  1269.1862003 , -6117.49479966],
#        [ 1262.77627758,  1281.90356936, -6111.60865171],
#        [ 1258.69725287,  1278.78916678, -6113.10236235],
#        [ 1261.63983387,  1284.0308773 , -6111.39678271],
#        [ 1262.5183328 ,  1283.42070739, -6111.34353045],
#        [ 1259.95587271,  1278.92274862, -6112.81512905],
#        [ 1241.81503048,  1263.87774958, -6119.65272415],
#        [ 1262.72287138,  1284.0533022 , -6111.16838806],
#        [ 1263.81019437,  1286.2031842 , -6110.49148281],
#        [ 1264.45834731,  1285.1952908 , -6110.5694622 ],
#        [ 1263.01867006,  1285.70489407, -6110.75999892],
#        [ 1263.76712481,  1285.52161605, -6110.6438146 ],
#        [ 1256.89197377,  1284.06701469, -6112.36741926],
#        [ 1254.44575495,  1278.87508859, -6113.95823961],
#        [ 1243.1017489 ,  1265.27732526, -6119.10224886],
#        [ 1263.87838869,  1286.72631924, -6110.36723921],
#        [ 1265.3562534 ,  1294.56794488, -6108.40473349],
#        [ 1258.3252328 ,  1286.17418076, -6111.62945418],
#        [ 1255.92333178,  1279.87780151, -6113.44505152],
#        [ 1263.10449041,  1285.41616892, -6110.80300116],
#        [ 1263.00034226,  1285.78445174, -6110.74704755],
#        [ 1260.20788231,  1284.78128132, -6111.534517  ],
#        [ 1250.44331393,  1273.47179279, -6115.90566569],
#        [ 1254.68156048,  1277.33328458, -6114.23215636],
#        [ 1261.8001001 ,  1285.64160879, -6111.02504995],
#        [ 1263.49051807,  1286.33577619, -6110.52968094],
#        [ 1260.10451133,  1278.68258948, -6112.8347316 ],
#        [ 1250.30716108,  1273.55310011, -6115.91657106],
#        [ 1261.12379986,  1286.33086492, -6111.01960947],
#        [ 1262.64384018,  1284.72071843, -6111.04444498],
#        [ 1259.14216759,  1284.01220494, -6111.91579289],
#        [ 1257.52734721,  1282.80324038, -6112.50209141],
#        [ 1256.17790322,  1278.31278556, -6113.72018478],
#        [ 1265.23655916,  1293.86300907, -6108.57888245],
#        [ 1254.10898407,  1278.76863908, -6114.04959285],
#        [ 1248.66852217,  1269.83295739, -6117.02478187],
#        [ 1260.47984151,  1279.3583391 , -6112.61595467],
#        [ 1263.35091067,  1285.51543869, -6110.7311783 ],
#        [ 1240.43481156,  1262.28404016, -6120.26155325],
#        [ 1253.56329412,  1276.4396087 , -6114.64814957],
#        [ 1258.01184643,  1283.70014319, -6112.21409447],
#        [ 1263.25685307,  1285.93795882, -6110.6617227 ],
#        [ 1262.71948337,  1287.26759491, -6110.49283163],
#        [ 1255.54549558,  1281.84827166, -6113.10980737],
#        [ 1258.74679274,  1281.80168783, -6112.46120191]])

# %%
# Greedy approach
def greedy_tsp(coordinates):
    remaining_locations = list(range(len(coordinates)))
    path = [remaining_locations.pop(0)] # Start from the first city
    while remaining_locations:
        current_location = path[-1]
        next_location = min(remaining_locations, key=lambda location: np.linalg.norm(coordinates[current_location] - coordinates[location]))
        path.append(next_location)
        remaining_locations.remove(next_location)
    return path

# %%
greedy_route = greedy_tsp(coordinates)

# %%
# Calculate the total distance of the travel route

# Calculate Euclidean distance between two locations
def distance(from_location, to_location):
    return np.linalg.norm(coordinates[from_location] - coordinates[to_location])

# Evaluate the total distance of the route
def evaluate(route):  
    distance_sum = sum(distance(route[i], route[i+1]) for i in range(len(route) - 1))
    distance_sum += distance(route[0], route[-1])  # Return to the starting location
    return distance_sum,

# %%
print("Route (Greedy Approach): ", greedy_route)
print("Route Distance (Greedy Approach): ", evaluate(greedy_route))
# Out:
# Route (Greedy Approach):  [0, 35, 45, 36, 2, 17, 22, 26, 8, 9, 12, 34, 3, 24, 42, 15, 25, 46, 30, 13, 4, 20, 16, 14, 47, 33, 29, 6, 41, 10, 31, 7, 37, 23, 18, 39, 28, 1, 44, 27, 32, 40, 5, 19, 11, 43, 48, 49, 38, 21]
# Route Distance (Greedy Approach):  (122.56455545609326,)

# %%
from deap import base, creator, tools, algorithms

num_locations = len(coordinates)



# Set up DEAP
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

toolbox = base.Toolbox()
toolbox.register("indices", random.sample, range(num_locations), num_locations)
toolbox.register("individual", tools.initIterate, creator.Individual, toolbox.indices)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("mate", tools.cxOrdered)
toolbox.register("mutate", tools.mutShuffleIndexes, indpb=0.05)
toolbox.register("select", tools.selTournament, tournsize=3)
toolbox.register("evaluate", evaluate)

def main():
    pop = toolbox.population(n=500)
    hof = tools.HallOfFame(1)
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("avg", np.mean)
    stats.register("min", np.min)

    pop, log = algorithms.eaSimple(pop, toolbox, 0.7, 0.2, 500, stats=stats, halloffame=hof, verbose=True)

    return pop, log, hof

if __name__ == "__main__":
    pop, log, hof = main()
    best_route = hof[0]
    print(f"Best Route (Genetic Algorithm): {best_route}")
    print(f"Route Distance (Genetic Algorithm): {evaluate(best_route)[0]}")
# Out:
# gen	nevals	avg    	min
# 0  	500   	511.635	370.623
# 1  	370   	487.904	359.849
# 2  	386   	467.955	354.243
# 3  	391   	450.106	357.043
# 4  	365   	435.02 	346.563
# 5  	390   	423.41 	320.441
# 6  	367   	405.521	321.922
# 7  	360   	392.178	286.463
# 8  	395   	382.012	286.463
# 9  	388   	367.025	286.463
# 10 	381   	359.284	288.388
# 11 	380   	354.698	267.738
# 12 	395   	346.667	270.702
# 13 	371   	340.028	261.231
# 14 	388   	333.147	254.872
# 15 	396   	327.374	251.063
# 16 	399   	325.09 	251.425
# 17 	375   	314.608	246.637
# 18 	376   	313.046	250.605
# 19 	384   	306.233	246.257
# 20 	410   	300.799	233.008
# 21 	370   	296.225	233.008
# 22 	377   	287.846	213.831
# 23 	403   	285.596	213.831
# 24 	373   	281.325	207.13
# 25 	384   	276.579	209.567
# 26 	373   	274.409	220.859
# 27 	376   	269.139	218.302
# 28 	389   	270.195	211.689
# 29 	387   	267.719	211.689
# 30 	391   	264.962	202.593
# 31 	377   	263.205	190.423
# 32 	364   	258.862	190.423
# 33 	376   	254.964	187.185
# 34 	368   	251.879	187.185
# 35 	387   	249.965	187.185
# 36 	397   	247.143	184.629
# 37 	373   	242.778	188.73
# 38 	380   	242.069	189.41
# 39 	383   	239.272	183.322
# 40 	385   	236.539	181.983
# 41 	372   	237.267	181.983
# 42 	381   	235.51 	180.628
# 43 	375   	234.001	180.628
# 44 	371   	232.334	177.542
# 45 	371   	232.294	180.628
# 46 	365   	222.58 	174.83
# 47 	390   	227.713	178.891
# 48 	389   	223.307	178.347
# 49 	401   	225.489	177.743
# 50 	378   	224.248	165.659
# 51 	377   	220.704	178.636
# 52 	368   	217.548	173.736
# 53 	374   	217.372	170.349
# 54 	399   	215.251	170.349
# 55 	383   	215.818	169.14
# 56 	380   	211.17 	168.78
# 57 	363   	214.249	167.808
# 58 	384   	209.055	167.728
# 59 	340   	208.308	166.73
# 60 	378   	205.13 	166.73
# 61 	362   	205.258	164.796
# 62 	376   	200.937	160.262
# 63 	355   	203.487	160.262
# 64 	373   	205.578	157.017
# 65 	365   	200.777	157.017
# 66 	385   	200.766	157.017
# 67 	374   	202.308	157.017
# 68 	372   	197.285	156.045
# 69 	369   	199.293	160.064
# 70 	375   	195.493	160.064
# 71 	390   	198.269	159.029
# 72 	371   	194.379	148.366
# 73 	391   	195.894	148.366
# 74 	388   	193.958	148.366
# 75 	384   	195.936	152.411
# 76 	376   	194.482	152.411
# 77 	381   	195.068	152.411
# 78 	395   	192.983	154.957
# 79 	391   	192.089	154.418
# 80 	377   	192.77 	154.418
# 81 	361   	188.675	152.954
# 82 	381   	192.781	152.396
# 83 	382   	192.156	150.925
# 84 	362   	189.057	152.217
# 85 	391   	188.027	150.303
# 86 	366   	184.893	148.247
# 87 	382   	186.184	148.247
# 88 	382   	185.448	148.247
# 89 	382   	186.095	148.907
# 90 	394   	186.847	146.934
# 91 	379   	182.496	146.934
# 92 	373   	182.526	144.099
# 93 	371   	180.632	145.529
# 94 	393   	181.562	147.158
# 95 	400   	178.7  	146.57
# 96 	373   	177.281	144.904
# 97 	371   	176.247	142.387
# 98 	393   	175.095	141.843
# 99 	364   	176.457	141.843
# 100	365   	175.631	141.843
# 101	383   	178.036	141.928
# 102	361   	172.191	139.701
# 103	378   	173.246	139.701
# 104	377   	174.019	139.701
# 105	402   	175.653	142.063
# 106	363   	173.361	140.903
# 107	381   	172.41 	139.777
# 108	380   	171.046	139.777
# 109	370   	170.07 	139.777
# 110	372   	171.134	139.777
# 111	379   	171.472	137.126
# 112	359   	168.903	137.808
# 113	380   	169.578	136.524
# 114	384   	169.32 	136.524
# 115	379   	169.739	133.777
# 116	409   	168.636	133.777
# 117	402   	171.172	133.777
# 118	369   	168.874	133.777
# 119	381   	172.134	133.777
# 120	378   	168.554	133.777
# 121	364   	166.019	134.448
# 122	361   	163.966	134.138
# 123	362   	164.636	133.141
# 124	384   	161.749	134.079
# 125	386   	163.688	132.505
# 126	358   	164.188	132.771
# 127	370   	161.759	132.76
# 128	374   	161.719	132.191
# 129	369   	159.331	133.096
# 130	365   	162.017	133.283
# 131	379   	161.595	131.586
# 132	396   	160.88 	131.586
# 133	357   	157.813	131.47
# 134	374   	160.519	131.838
# 135	412   	163.336	131.259
# 136	355   	159.611	131.363
# 137	393   	159.7  	129.951
# 138	378   	160.864	129.951
# 139	369   	155.187	129.951
# 140	380   	155.868	128.827
# 141	356   	159.555	128.827
# 142	403   	156.865	128.546
# 143	397   	155.832	128.556
# 144	380   	152.919	128.46
# 145	370   	152.778	128.078
# 146	378   	154.886	126.247
# 147	394   	160.372	126.247
# 148	378   	156.791	126.247
# 149	369   	155.204	126.247
# 150	381   	158.1  	126.077
# 151	381   	156.377	124.525
# 152	402   	153.871	126.077
# 153	369   	153.352	126.077
# 154	371   	158.128	125.058
# 155	394   	155.608	124.525
# 156	361   	155.866	124.525
# 157	355   	152.956	125.058
# 158	388   	151.862	123.653
# 159	385   	150.848	123.146
# 160	375   	153.633	123.146
# 161	361   	150.396	123.146
# 162	373   	146.492	122.956
# 163	383   	146.165	123.146
# 164	360   	145.218	123.146
# 165	387   	148    	123.146
# 166	381   	150.266	123.01
# 167	375   	146.933	122.94
# 168	376   	144.752	121.483
# 169	387   	144.761	121.92
# 170	367   	143.075	121.483
# 171	387   	142.608	121.467
# 172	382   	143.858	121.467
# 173	379   	143.303	121.438
# 174	392   	144.874	121.33
# 175	400   	143.285	121.33
# 176	374   	143.208	121.207
# 177	363   	142.65 	121.207
# 178	394   	144.295	121.197
# 179	365   	138.443	121.135
# 180	376   	138.429	121.305
# 181	384   	142.332	121.269
# 182	362   	139.647	121.181
# 183	366   	140.619	121.002
# 184	386   	142.145	120.666
# 185	403   	139.041	120.666
# 186	377   	139.752	120.581
# 187	381   	140.472	120.61
# 188	396   	139.571	120.621
# 189	382   	141.525	120.605
# 190	391   	142.658	120.565
# 191	388   	143.331	120.024
# 192	391   	143.056	120.024
# 193	354   	138.428	120.008
# 194	386   	139.028	119.585
# 195	390   	140.888	120.008
# 196	367   	139.045	119.968
# 197	386   	139.806	119.968
# 198	368   	138.855	119.968
# 199	389   	138.012	119.784
# 200	372   	135.27 	119.585
# 201	373   	135.424	119.585
# 202	366   	135.587	119.585
# 203	370   	130.642	119.585
# 204	395   	137.232	119.585
# 205	400   	138.396	119.585
# 206	382   	137.388	119.585
# 207	373   	137.578	119.402
# 208	368   	138.672	119.315
# 209	381   	141.25 	119.315
# 210	390   	139.191	119.315
# 211	380   	137.224	119.315
# 212	388   	136.329	118.474
# 213	392   	139.253	118.474
# 214	374   	137.397	118.204
# 215	369   	135.705	118.204
# 216	375   	138.451	118.204
# 217	367   	134.632	118.204
# 218	386   	137.718	117.869
# 219	378   	137.589	117.869
# 220	387   	136.424	117.869
# 221	384   	139.248	117.824
# 222	359   	138.076	117.824
# 223	376   	135.484	117.703
# 224	380   	138.952	117.703
# 225	386   	132.067	117.368
# 226	382   	133.955	117.322
# 227	385   	134.681	117.199
# 228	369   	135.878	117.199
# 229	381   	135.682	115.744
# 230	358   	134.536	115.744
# 231	358   	134.402	115.744
# 232	377   	131.025	115.699
# 233	370   	129.438	115.699
# 234	387   	133.557	115.699
# 235	387   	136.079	115.699
# 236	388   	132.152	115.664
# 237	387   	132.039	115.664
# 238	396   	132.713	115.664
# 239	372   	132.873	115.664
# 240	385   	130.637	115.644
# 241	392   	131.403	115.644
# 242	381   	132.049	115.644
# 243	387   	129.814	115.46
# 244	379   	130.804	115.46
# 245	403   	133.173	115.46
# 246	365   	128.528	115.46
# 247	377   	127.485	115.46
# 248	373   	133.024	115.46
# 249	393   	131.232	115.46
# 250	383   	132.98 	115.46
# 251	359   	127.915	115.46
# 252	384   	128.968	115.46
# 253	376   	132.996	115.46
# 254	375   	129.53 	115.46
# 255	373   	125.933	115.46
# 256	377   	130.89 	115.46
# 257	380   	129.641	115.46
# 258	379   	135.202	115.46
# 259	372   	129.799	115.46
# 260	394   	126.935	115.46
# 261	375   	128.079	115.46
# 262	375   	131.556	115.46
# 263	370   	131.113	115.46
# 264	384   	131.274	115.46
# 265	364   	128.703	115.46
# 266	370   	130.984	115.46
# 267	395   	133.824	115.46
# 268	367   	128.98 	115.46
# 269	376   	132.19 	115.46
# 270	376   	132.363	115.46
# 271	393   	129.666	115.46
# 272	396   	128.955	115.46
# 273	368   	128.719	115.46
# 274	389   	131.889	115.46
# 275	368   	131.47 	115.46
# 276	386   	130.941	115.46
# 277	398   	128.298	115.46
# 278	391   	129.628	115.46
# 279	360   	129.268	115.46
# 280	383   	134.379	115.46
# 281	370   	131.352	115.46
# 282	394   	131.92 	115.46
# 283	389   	134.139	115.46
# 284	391   	132.065	115.46
# 285	403   	132.411	115.46
# 286	382   	130.603	115.46
# 287	387   	129.525	115.46
# 288	370   	131.541	115.46
# 289	386   	128.415	115.46
# 290	392   	132.885	115.46
# 291	373   	130.24 	115.46
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-53fec8febcc3> in <module>
#      40
#      41 if __name__ == "__main__":
# ---> 42     pop, log, hof = main()
#      43     best_route = hof[0]
#      44     print(f"Best Route (Genetic Algorithm): {best_route}")
#
# <ipython-input-68-53fec8febcc3> in main()
#      35     stats.register("min", np.min)
#      36
# ---> 37     pop, log = algorithms.eaSimple(pop, toolbox, 0.7, 0.2, 500, stats=stats, halloffame=hof, verbose=True)
#      38
#      39     return pop, log, hof
#
# ~\anaconda3\lib\site-packages\deap\algorithms.py in eaSimple(population, toolbox, cxpb, mutpb, ngen, stats, halloffame, verbose)
#     166
#     167         # Vary the pool of individuals
# --> 168         offspring = varAnd(offspring, toolbox, cxpb, mutpb)
#     169
#     170         # Evaluate the individuals with an invalid fitness
#
# ~\anaconda3\lib\site-packages\deap\algorithms.py in varAnd(population, toolbox, cxpb, mutpb)
#      77     for i in range(len(offspring)):
#      78         if random.random() < mutpb:
# ---> 79             offspring[i], = toolbox.mutate(offspring[i])
#      80             del offspring[i].fitness.values
#      81
#
# ~\anaconda3\lib\site-packages\deap\tools\mutation.py in mutShuffleIndexes(individual, indpb)
#     111     size = len(individual)
#     112     for i in range(size):
# --> 113         if random.random() < indpb:
#     114             swap_indx = random.randint(0, size - 2)
#     115             if swap_indx >= i:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Recommended Readings
#
# Pending.

# %% [markdown]
# ## Optional Readings
#
# You will find additional resources in case you would like to continue exploring the topics covered in this module below.
#
# Pending.
